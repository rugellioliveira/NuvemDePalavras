# %% [markdown]
# <a href="https://colab.research.google.com/github/rugellioliveira/NuvemDePalavras/blob/main/NuvemDePalavras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# As **Word Clouds** (também conhecidas como wordle, word collage ou tag cloud) são representações visuais de palavras que dão maior destaque às palavras que aparecem com mais frequência.

# %%
! pip install WordCloud

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Frases para teste
Frase = 'Lorem Ipsum é simplesmente uma simulação de texto da indústria tipográfica e de impressos, e vem sendo utilizado desde o século XVI, quando um impressor desconhecido pegou uma bandeja de tipos e os embaralhou para fazer um livro de modelos de tipos. Lorem Ipsum sobreviveu não só a cinco séculos, como também ao salto para a editoração eletrônica, permanecendo essencialmente inalterado. Se popularizou na década de 60, quando a Letraset lançou decalques contendo passagens de Lorem Ipsum, e mais recentemente quando passou a ser integrado a softwares de editoração eletrônica como Aldus PageMaker.'
Frase = Frase + 'Ao contrário da crença popular, Lorem Ipsum não é simplesmente um texto aleatório. Tem raízes em uma peça da literatura clássica latina de 45 aC, com mais de 2.000 anos. Richard McClintock, um professor de latim no Hampden-Sydney College, na Virgínia, pesquisou uma das palavras latinas mais obscuras, consectetur, de uma passagem de Lorem Ipsum e, examinando as citações da palavra na literatura clássica, descobriu a fonte indubitável. Lorem Ipsum vem das seções 1.10.32 e 1.10.33 de "de Finibus Bonorum et Malorum" (Os Extremos do Bem e do Mal) de Cícero, escrito em 45 aC. Este livro é um tratado sobre a teoria da ética, muito popular durante o Renascimento. A primeira linha de Lorem Ipsum, "Lorem ipsum dolor sit amet ..", vem de uma linha na seção 1.10.32.'

# %%
Frase
# Out:
# 'Lorem Ipsum é simplesmente uma simulação de texto da indústria tipográfica e de impressos, e vem sendo utilizado desde o século XVI, quando um impressor desconhecido pegou uma bandeja de tipos e os embaralhou para fazer um livro de modelos de tipos. Lorem Ipsum sobreviveu não só a cinco séculos, como também ao salto para a editoração eletrônica, permanecendo essencialmente inalterado. Se popularizou na década de 60, quando a Letraset lançou decalques contendo passagens de Lorem Ipsum, e mais recentemente quando passou a ser integrado a softwares de editoração eletrônica como Aldus PageMaker.Ao contrário da crença popular, Lorem Ipsum não é simplesmente um texto aleatório. Tem raízes em uma peça da literatura clássica latina de 45 aC, com mais de 2.000 anos. Richard McClintock, um professor de latim no Hampden-Sydney College, na Virgínia, pesquisou uma das palavras latinas mais obscuras, consectetur, de uma passagem de Lorem Ipsum e, examinando as citações da palavra na literatura cl
# ...

# %%
# Gerar Nuvem de Palavras
Nuvem_Palavras = WordCloud(
    background_color='black',
    width=1600,
    height=1000
).generate( Frase )

# %%
print(Nuvem_Palavras)

# %%
# Cria figura para exibir a nuvem de palavras

fig, ax = plt.subplots( figsize=(10, 7) )
ax.imshow( Nuvem_Palavras, interpolation='bilinear' ) #plota as palavras na figura
ax.set_axis_off()  #desabilita eixos da figura

# %% [markdown]
# **Novo exemplo:**

# %%
# Cria lista de palavras
Lista_Palavras = ['Python', 'Python', 'Python', 'Java', 'Java', 'R', 'JavaScript', 'Cobol', 'SQL', 'SQL', 'SQL', 'Python é top!']

# Cria uma tabela no Pandas para ilustrar como se fosse uma tabela "base de dados"
Base_Dados = pd.DataFrame( Lista_Palavras, columns={'Palavras':'Palavras'} )

# Verificando a tabela
Base_Dados
# Out:
#          Palavras
# 0          Python
# 1          Python
# 2          Python
# 3            Java
# 4            Java
# 5               R
# 6      JavaScript
# 7           Cobol
# 8             SQL
# 9             SQL
# 10            SQL
# 11  Python é top!

# %%
#Forma frase com as palavras da lista
Juntar_palavras = ''

for Palavra in Base_Dados['Palavras']:
  Juntar_palavras = Juntar_palavras + ' ' + Palavra

#Verifica a variável
Juntar_palavras
# Out:
# ' Python Python Python Java Java R JavaScript Cobol SQL SQL SQL Python é top!'

# %%
# Gera Nuvem de Palavras
Nuvem_Lista_Palavras = WordCloud(
    background_color='black',
    width=1600,
    height=1000
).generate( Juntar_palavras )

# Cria a figura com a plotagem das palavras
fig, ax = plt.subplots( figsize=(10, 7) )
ax.imshow( Nuvem_Lista_Palavras, interpolation='bilinear' )
ax.set_axis_off()

# %% [markdown]
# **Tratando Frases:**
#
# O Natural Language Toolkit , ou mais comumente NLTK , é um conjunto de bibliotecas e programas para processamento de linguagem natural (NLP) simbólico e estatístico para inglês escrito na linguagem de programação Python .

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#Filtra as palavras de parada
Lista_Stopwords = nltk.corpus.stopwords.words('portuguese')

#Verificando primeiras 10 palavras da lista
print( Lista_Stopwords[:10], '\n')

#Quantidade de Palavras
print(f'Temos {len(Lista_Stopwords)} palavras.')
# Out:
# ['a', 'à', 'ao', 'aos', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aquilo', 'as']
#
# Temos 207 palavras.

# %%
# Frase para teste
Frase_02 = ''' Nunca deixe ninguém te dizer que não pode fazer alguma coisa.
Se você tem um sonho tem que correr atrás dele.
As pessoas não conseguem vencer e dizem que você também não vai vencer.
Se você quer uma coisa corre atrás. '''

# %%
# Variável para somar as palavras retiradas
Palavras_Retiradas = 0

# Calcula total de palavras na frase
Palavras_na_Frase = len(Frase_02.split())
print(Palavras_na_Frase)
# Out:
# 41

# %%
Nova_Frase = ''

# Loop para retirar as Stopswords
for Palavra in Frase_02.split():

  #Se a palavra não estiver na lista
  if Palavra not in Lista_Palavras:
    Nova_Frase += Palavra

  #Se a palavras estiver na lista
  else:
    Palavras_Retiradas += 1

#Vericando resultado
print(f'Frase tinha {len(Frase_02.split())} palavras e agora ficou com {len(Nova_Frase.split())} palavras')
# Out:
# Frase tinha 41 palavras e agora ficou com 1 palavras
